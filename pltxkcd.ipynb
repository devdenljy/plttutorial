# %%
import matplotlib.pyplot as plt

import numpy as np

zdata = 15 * np.random.random(150)

xdata = np.sin(zdata) + 0.1 ** np.random.randn(150)

ydata = np.cos(zdata) + 1.0 * np.random.randn(150)

np.cos(zdata)

np.sin(zdata)

np.logspace(0.1, 10.00)

np.linspace(1.0, 10.00)

np.geomspace(0.1, 10.00)

from mpl_toolkits.mplot3d import Axes3D

with plt.xkcd():

    fig = plt.figure()

    ax = fig.gca(projection='3d')

    ax.plot(np.logspace(0.1, 10.00), np.geomspace(0.1, 10.00), np.linspace(1.0, 10.00), '-')

    ax.scatter3D(xdata, zdata, c=zdata, cmap='Greens');
# Out:
# C:\Anaconda3\Script\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Anaconda3\Script\lib\site-packages\numpy\.libs\libopenblas.U35RT5X5BPDSH5ZTF276YADQR2KDU6PR.gfortran-win32.dll
# C:\Anaconda3\Script\lib\site-packages\numpy\.libs\libopenblas.VTYUM5MXKVFE4PZZER3L7PNO6YB4XFF3.gfortran-win32.dll
#   stacklevel=1)
